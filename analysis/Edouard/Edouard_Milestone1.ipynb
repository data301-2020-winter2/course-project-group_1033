# %%
import pandas as pd 


file = pd.read_csv("../../data/raw/nomenclature.csv")

file.head()
# Out:
#                                                    # Unnamed: 1 Unnamed: 2  \
# 0             # Nomenclature for Solar system bodies        NaN        NaN
# 1                                                  #        NaN        NaN
# 2  # Nomenclature data was obtained from the web ...        NaN        NaN
# 3                                                  #        NaN        NaN
# 4  # One rule per line. Each rule contains seven ...        NaN        NaN
#
#   Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0        NaN         NaN         NaN         NaN
# 1        NaN         NaN         NaN         NaN
# 2        NaN         NaN         NaN         NaN
# 3        NaN         NaN         NaN         NaN
# 4        NaN         NaN         NaN         NaN
