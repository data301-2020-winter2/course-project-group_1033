# %%
#import sys
#sys.path.append("..")
from scripts import project_functions # This is called a relative import
import pandas as pd
import numpy as np


df = project_functions.load_and_process("../../data/raw/nomenclature.csv")
df
# Out:
#        index Planet Name       ID        FeatureName       FeatureType  \
# 0       1357        Mars   4574.0   Pandorae Fretum    albedo feature
# 1       1459        Mars   6596.0            Xanthe    albedo feature
# 2       1168        Mars   2132.0             Gehon    albedo feature
# 3       1462        Mars   6639.0      Yaonis Regio    albedo feature
# 4       1165        Mars   4213.0   Nereidum Fretum    albedo feature
# ...      ...         ...      ...                ...               ...
# 15667    828       Titan   7007.0       Hobal Virga             virga
# 15668    860       Titan   7008.0     Kalseru Virga             virga
# 15669    861       Titan   7009.0   Shiwanni Virgae             virga
# 15670    987       Titan  15352.0   Tishtrya Virgae             virga
# 15671    781       Titan  14658.0      Uanui Virgae             virga
#
#       Planetary Feature  Latitude of Center of Planetary Feature  \
# 0                    AL                               -24.741878
# 1                    AL                                 9.884955
# 2                    AL                                14.831743
# 3                    AL                               -39.667248
# 4                    AL                               -44.661768
# ...                 ...                                      ...
# 15667                VI                               -35.000000
# 15668                VI                               -36.000000
# 15669                VI                               -25.000000
# 15670                VI                                23.836026
# 15671                VI                                45.200000
#
#        Longitude of Center of Planetary Feature  Size of Planetary Feature(km)
# 0                                     44.000000                            0.0
# 1                                    310.000000                            0.0
# 2                                    360.000000                            0.0
# 3                                     40.000000                            0.0
# 4                                    305.000000                            0.0
# ...                                         ...                            ...
# 15667                                194.000000                         1075.0
# 15668                                223.000000                          630.0
# 15669                                328.000000                         1400.0
# 15670                                180.245045                          276.0
# 15671                                124.700000                          917.0
#
# [15672 rows x 9 columns]
